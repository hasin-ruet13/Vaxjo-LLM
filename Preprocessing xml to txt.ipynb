# %%
import xml.etree.ElementTree as ET
import os

def extract_plaintext_from_pmc_xml(xml_file_path):
    """
    Parses a single PMC XML file and returns a dictionary with the
    extracted title and body text, including tables. Returns None on failure.
    """
    try:
        # 1. Parse the XML file
        tree = ET.parse(xml_file_path)
        root = tree.getroot()

        # 2. Extract the article title
        title_element = root.find(".//article-title")
        title = "".join(title_element.itertext()).strip() if title_element is not None else "No Title Found"

        # 3. Extract the main body of the article, handling paragraphs and tables
        body_element = root.find(".//body")
        
        body_content_parts = []
        if body_element is not None:
            # We'll recursively walk the body to find relevant text
            for child in body_element.iter():
                # Process paragraphs
                if child.tag == 'p':
                    # Use itertext() to get all text including text from nested tags (like xref)
                    # then join it and strip whitespace.
                    paragraph_text = "".join(child.itertext()).strip()
                    if paragraph_text:
                        body_content_parts.append(paragraph_text)
                
                # Process tables
                elif child.tag == 'table-wrap':
                    table_text = extract_table_content(child)
                    if table_text:
                        body_content_parts.append(table_text)
        
        body_text = "\n\n".join(body_content_parts) if body_content_parts else "No Body Found"

        return {
            "title": title,
            "body": body_text
        }

    except ET.ParseError as e:
        print(f"Error parsing XML file {xml_file_path}: {e}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred with {xml_file_path}: {e}")
        return None

def extract_table_content(table_wrap_element):
    """
    Extracts the caption, headers, and cell data from a <table-wrap> element
    and formats it into a readable plaintext string.
    """
    table_parts = []

    # Extract table label and caption
    caption_element = table_wrap_element.find(".//caption")
    caption_text = "".join(caption_element.itertext()).strip() if caption_element is not None else ""
    label_element = table_wrap_element.find(".//label")
    label = "".join(label_element.itertext()).strip() if label_element is not None else "Table"
    
    if caption_text:
        table_parts.append(f"{label}: {caption_text}")
    elif label:
        table_parts.append(f"{label}")

    # Extract table headers
    headers = []
    header_elements = table_wrap_element.findall(".//thead//th")
    for th in header_elements:
        header_text = "".join(th.itertext()).strip()
        headers.append(header_text)
    
    if headers:
        table_parts.append(" | ".join(headers))
        table_parts.append("-" * 50) # A separator line

    # Extract table rows
    rows = table_wrap_element.findall(".//tbody//tr")
    for row in rows:
        cells = []
        cell_elements = row.findall(".//td")
        for td in cell_elements:
            cell_text = "".join(td.itertext()).strip()
            # Clean up the text by removing reference tags like [<xref>]
            clean_text = ' '.join(cell_text.split()) # This will remove extra spaces
            cells.append(clean_text)
        
        # Only add the row if it's not empty
        if any(cells):
            table_parts.append(" | ".join(cells))
    
    return "\n".join(table_parts) if table_parts else ""


def process_all_xml_in_folder(input_folder, output_folder):
    """
    Iterates through all XML files in a folder, extracts plaintext from each,
    and saves the results to a new folder.
    """
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        print(f"Created output directory: {output_folder}")
    
    # Check if the input folder exists
    if not os.path.exists(input_folder):
        print(f"Error: The specified input folder '{input_folder}' does not exist.")
        return
        
    xml_files = [f for f in os.listdir(input_folder) if f.endswith(".xml")]
    if not xml_files:
        print(f"No XML files found in the directory: {input_folder}")
        return
        
    print(f"Found {len(xml_files)} XML files to process.")

    for filename in xml_files:
        xml_path = os.path.join(input_folder, filename)
        
        print(f"Processing {filename}...")
        
        # Call the parsing function
        plaintext_data = extract_plaintext_from_pmc_xml(xml_path)
        
        if plaintext_data:
            # Assemble the final plaintext content
            plaintext_content = f"Title: {plaintext_data['title']}\n\n{plaintext_data['body']}"
            
            # Create a filename for the output file
            base_name = os.path.splitext(filename)[0]
            output_file_path = os.path.join(output_folder, f"{base_name}.txt")
            
            # Save the plaintext to a new file
            with open(output_file_path, "w", encoding="utf-8") as f:
                f.write(plaintext_content)
                
            print(f" -> Saved plaintext to {output_file_path}\n")
        else:
            print(f" -> Failed to process {filename}. Skipping.\n")


# --- Main Execution ---
if __name__ == "__main__":
    # --- Configuration ---
    # Path to the folder containing your downloaded XML files
    # This path is based on your request.
    input_folder = "Dataset/Dataset_PMC_Filtered_Reviews/"
    # Path to the folder where the plaintext files will be saved
    output_folder = "Dataset/PMC_Filtered_Reviews_plaintext_gemini"

    # Run the batch processing function
    process_all_xml_in_folder(input_folder, output_folder)
# Out:
# Found 603 XML files to process.
# Processing PMC4916179.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC4916179.txt
#
# Processing PMC10458802.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10458802.txt
#
# Processing PMC11892266.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11892266.txt
#
# Processing PMC8828558.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8828558.txt
#
# Processing PMC10968813.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10968813.txt
#
# Processing PMC11379892.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11379892.txt
#
# Processing PMC9092649.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9092649.txt
#
# Processing PMC6669641.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6669641.txt
#
# Processing PMC11171065.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11171065.txt
#
# Processing PMC5874648.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5874648.txt
#
# Processing PMC8301306.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8301306.txt
#
# Processing PMC8116645.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8116645.txt
#
# Processing PMC7497069.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7497069.txt
#
# Processing PMC8101866.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8101866.txt
#
# Processing PMC8190278.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8190278.txt
#
# Processing PMC9687436.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9687436.txt
#
# Processing PMC11511416.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11511416.txt
#
# Processing PMC12197412.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12197412.txt
#
# Processing PMC9280161.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9280161.txt
#
# Processing PMC7159032.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7159032.txt
#
# Processing PMC11748575.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11748575.txt
#
# Processing PMC5215580.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5215580.txt
#
# Processing PMC7194457.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7194457.txt
#
# Processing PMC7816567.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7816567.txt
#
# Processing PMC10185832.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10185832.txt
#
# Processing PMC7563765.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7563765.txt
#
# Processing PMC7837099.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7837099.txt
#
# Processing PMC10465871.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10465871.txt
#
# Processing PMC6466432.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6466432.txt
#
# Processing PMC8795326.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8795326.txt
#
# Processing PMC6030256.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6030256.txt
#
# Processing PMC10977417.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10977417.txt
#
# Processing PMC8726002.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8726002.txt
#
# Processing PMC12094284.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12094284.txt
#
# Processing PMC5995208.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5995208.txt
#
# Processing PMC7883962.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7883962.txt
#
# Processing PMC10468591.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10468591.txt
#
# Processing PMC6466149.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6466149.txt
#
# Processing PMC9047653.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9047653.txt
#
# Processing PMC7564472.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7564472.txt
#
# Processing PMC7871111.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7871111.txt
#
# Processing PMC5340775.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5340775.txt
#
# Processing PMC7111479.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7111479.txt
#
# Processing PMC7978427.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7978427.txt
#
# Processing PMC7349526.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7349526.txt
#
# Processing PMC7663252.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7663252.txt
#
# Processing PMC7927599.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7927599.txt
#
# Processing PMC6349827.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6349827.txt
#
# Processing PMC6677153.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6677153.txt
#
# Processing PMC8049400.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8049400.txt
#
# Processing PMC9282651.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9282651.txt
#
# Processing PMC7757035.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7757035.txt
#
# Processing PMC10962113.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10962113.txt
#
# Processing PMC9321285.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9321285.txt
#
# Processing PMC8160852.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8160852.txt
#
# Processing PMC7894273.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7894273.txt
#
# Processing PMC10974975.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10974975.txt
#
# Processing PMC7605856.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7605856.txt
#
# Processing PMC7350342.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7350342.txt
#
# Processing PMC7050619.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7050619.txt
#
# Processing PMC6476043.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6476043.txt
#
# Processing PMC10121800.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10121800.txt
#
# Processing PMC8771143.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8771143.txt
#
# Processing PMC7423510.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7423510.txt
#
# Processing PMC10459455.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10459455.txt
#
# Processing PMC10985213.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10985213.txt
#
# Processing PMC8674100.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8674100.txt
#
# Processing PMC11876029.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11876029.txt
#
# Processing PMC8233758.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8233758.txt
#
# Processing PMC10536331.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10536331.txt
#
# Processing PMC8722410.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8722410.txt
#
# Processing PMC6567157.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6567157.txt
#
# Processing PMC9616470.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9616470.txt
#
# Processing PMC9513067.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9513067.txt
#
# Processing PMC12193398.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12193398.txt
#
# Processing PMC9404695.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9404695.txt
#
# Processing PMC8145166.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8145166.txt
#
# Processing PMC9737588.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9737588.txt
#
# Processing PMC10303573.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10303573.txt
#
# Processing PMC8459551.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8459551.txt
#
# Processing PMC7723964.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7723964.txt
#
# Processing PMC7879001.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7879001.txt
#
# Processing PMC5642635.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5642635.txt
#
# Processing PMC11615947.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11615947.txt
#
# Processing PMC8227888.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8227888.txt
#
# Processing PMC7398286.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7398286.txt
#
# Processing PMC8106186.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8106186.txt
#
# Processing PMC11221474.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11221474.txt
#
# Processing PMC7711057.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7711057.txt
#
# Processing PMC9917907.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9917907.txt
#
# Processing PMC11155708.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11155708.txt
#
# Processing PMC7694192.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7694192.txt
#
# Processing PMC12257104.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12257104.txt
#
# Processing PMC7812346.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7812346.txt
#
# Processing PMC11754781.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11754781.txt
#
# Processing PMC10341809.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10341809.txt
#
# Processing PMC5079805.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5079805.txt
#
# Processing PMC10301501.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10301501.txt
#
# Processing PMC12030840.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12030840.txt
#
# Processing PMC7511675.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7511675.txt
#
# Processing PMC8324454.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8324454.txt
#
# Processing PMC12115399.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12115399.txt
#
# Processing PMC9115682.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9115682.txt
#
# Processing PMC10048722.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10048722.txt
#
# Processing PMC7857113.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7857113.txt
#
# Processing PMC8582592.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8582592.txt
#
# Processing PMC9768462.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9768462.txt
#
# Processing PMC11680146.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11680146.txt
#
# Processing PMC9927404.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9927404.txt
#
# Processing PMC11317272.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11317272.txt
#
# Processing PMC8515900.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8515900.txt
#
# Processing PMC7260574.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7260574.txt
#
# Processing PMC9414397.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9414397.txt
#
# Processing PMC9614730.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9614730.txt
#
# Processing PMC10356842.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10356842.txt
#
# Processing PMC7831445.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7831445.txt
#
# Processing PMC7265684.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7265684.txt
#
# Processing PMC9405528.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9405528.txt
#
# Processing PMC7793902.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7793902.txt
#
# Processing PMC7431783.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7431783.txt
#
# Processing PMC7157724.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7157724.txt
#
# Processing PMC9493399.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9493399.txt
#
# Processing PMC11859086.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11859086.txt
#
# Processing PMC7677683.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7677683.txt
#
# Processing PMC10059828.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10059828.txt
#
# Processing PMC11141480.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11141480.txt
#
# Processing PMC7589362.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7589362.txt
#
# Processing PMC8694750.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8694750.txt
#
# Processing PMC10013823.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10013823.txt
#
# Processing PMC8431817.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8431817.txt
#
# Processing PMC11554974.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11554974.txt
#
# Processing PMC7466534.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7466534.txt
#
# Processing PMC7655734.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7655734.txt
#
# Processing PMC7759095.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7759095.txt
#
# Processing PMC4929720.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC4929720.txt
#
# Processing PMC9530253.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9530253.txt
#
# Processing PMC11595984.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11595984.txt
#
# Processing PMC11170481.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11170481.txt
#
# Processing PMC9938630.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9938630.txt
#
# Processing PMC11684802.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11684802.txt
#
# Processing PMC6274812.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6274812.txt
#
# Processing PMC5729844.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5729844.txt
#
# Processing PMC10067403.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10067403.txt
#
# Processing PMC6923730.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6923730.txt
#
# Processing PMC11945129.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11945129.txt
#
# Processing PMC8553742.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8553742.txt
#
# Processing PMC9964829.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9964829.txt
#
# Processing PMC6789775.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6789775.txt
#
# Processing PMC7467145.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7467145.txt
#
# Processing PMC7405756.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7405756.txt
#
# Processing PMC10453274.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10453274.txt
#
# Processing PMC7712070.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7712070.txt
#
# Processing PMC8402453.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8402453.txt
#
# Processing PMC9187843.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9187843.txt
#
# Processing PMC7409282.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7409282.txt
#
# Processing PMC8185206.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8185206.txt
#
# Processing PMC5893894.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5893894.txt
#
# Processing PMC6963626.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6963626.txt
#
# Processing PMC7910145.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7910145.txt
#
# Processing PMC9772435.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9772435.txt
#
# Processing PMC7150928.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7150928.txt
#
# Processing PMC11435826.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11435826.txt
#
# Processing PMC9726273.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9726273.txt
#
# Processing PMC12031513.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12031513.txt
#
# Processing PMC8734653.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8734653.txt
#
# Processing PMC7905985.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7905985.txt
#
# Processing PMC9812358.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9812358.txt
#
# Processing PMC7350246.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7350246.txt
#
# Processing PMC7901381.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7901381.txt
#
# Processing PMC6356514.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6356514.txt
#
# Processing PMC10776678.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10776678.txt
#
# Processing PMC10295010.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10295010.txt
#
# Processing PMC10913723.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10913723.txt
#
# Processing PMC8865753.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8865753.txt
#
# Processing PMC8225176.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8225176.txt
#
# Processing PMC9788126.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9788126.txt
#
# Processing PMC9124800.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9124800.txt
#
# Processing PMC6223008.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6223008.txt
#
# Processing PMC11858194.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11858194.txt
#
# Processing PMC7392072.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7392072.txt
#
# Processing PMC7937508.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7937508.txt
#
# Processing PMC7465679.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7465679.txt
#
# Processing PMC9418019.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9418019.txt
#
# Processing PMC11392799.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11392799.txt
#
# Processing PMC11598945.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11598945.txt
#
# Processing PMC9149150.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9149150.txt
#
# Processing PMC9137434.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9137434.txt
#
# Processing PMC9063628.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9063628.txt
#
# Processing PMC7699502.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7699502.txt
#
# Processing PMC5733358.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5733358.txt
#
# Processing PMC11423863.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11423863.txt
#
# Processing PMC6105696.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6105696.txt
#
# Processing PMC9044961.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9044961.txt
#
# Processing PMC7179680.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7179680.txt
#
# Processing PMC8147386.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8147386.txt
#
# Processing PMC7422826.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7422826.txt
#
# Processing PMC4922024.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC4922024.txt
#
# Processing PMC8712944.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8712944.txt
#
# Processing PMC5048363.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5048363.txt
#
# Processing PMC11864319.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11864319.txt
#
# Processing PMC5834428.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5834428.txt
#
# Processing PMC5711983.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5711983.txt
#
# Processing PMC10134813.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10134813.txt
#
# Processing PMC8033039.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8033039.txt
#
# Processing PMC8678218.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8678218.txt
#
# Processing PMC7733686.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7733686.txt
#
# Processing PMC11769099.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11769099.txt
#
# Processing PMC12268350.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12268350.txt
#
# Processing PMC12114985.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12114985.txt
#
# Processing PMC8853290.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8853290.txt
#
# Processing PMC9998285.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9998285.txt
#
# Processing PMC11242184.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11242184.txt
#
# Processing PMC7597597.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7597597.txt
#
# Processing PMC11792077.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11792077.txt
#
# Processing PMC5827355.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5827355.txt
#
# Processing PMC7688745.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7688745.txt
#
# Processing PMC8619927.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8619927.txt
#
# Processing PMC7195550.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7195550.txt
#
# Processing PMC10385070.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10385070.txt
#
# Processing PMC7836388.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7836388.txt
#
# Processing PMC10014862.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10014862.txt
#
# Processing PMC8757994.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8757994.txt
#
# Processing PMC8866702.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8866702.txt
#
# Processing PMC11861685.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11861685.txt
#
# Processing PMC11437400.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11437400.txt
#
# Processing PMC5467010.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5467010.txt
#
# Processing PMC7785583.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7785583.txt
#
# Processing PMC4931635.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC4931635.txt
#
# Processing PMC5697410.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5697410.txt
#
# Processing PMC7240201.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7240201.txt
#
# Processing PMC9981536.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9981536.txt
#
# Processing PMC11125637.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11125637.txt
#
# Processing PMC8936379.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8936379.txt
#
# Processing PMC11019575.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11019575.txt
#
# Processing PMC6831456.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6831456.txt
#
# Processing PMC8166496.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8166496.txt
#
# Processing PMC6290032.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6290032.txt
#
# Processing PMC8007559.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8007559.txt
#
# Processing PMC9015098.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9015098.txt
#
# Processing PMC7983051.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7983051.txt
#
# Processing PMC7555229.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7555229.txt
#
# Processing PMC11434819.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11434819.txt
#
# Processing PMC10790774.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10790774.txt
#
# Processing PMC8346354.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8346354.txt
#
# Processing PMC8381795.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8381795.txt
#
# Processing PMC6036114.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6036114.txt
#
# Processing PMC10471115.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10471115.txt
#
# Processing PMC7349596.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7349596.txt
#
# Processing PMC8299593.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8299593.txt
#
# Processing PMC5354570.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5354570.txt
#
# Processing PMC7762175.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7762175.txt
#
# Processing PMC12203974.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12203974.txt
#
# Processing PMC7174737.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7174737.txt
#
# Processing PMC11590659.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11590659.txt
#
# Processing PMC7918810.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7918810.txt
#
# Processing PMC7785334.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7785334.txt
#
# Processing PMC10458847.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10458847.txt
#
# Processing PMC9554396.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9554396.txt
#
# Processing PMC8638329.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8638329.txt
#
# Processing PMC7858666.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7858666.txt
#
# Processing PMC10305121.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10305121.txt
#
# Processing PMC9857197.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9857197.txt
#
# Processing PMC9148927.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9148927.txt
#
# Processing PMC9162156.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9162156.txt
#
# Processing PMC11319164.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11319164.txt
#
# Processing PMC6637046.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6637046.txt
#
# Processing PMC7151053.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7151053.txt
#
# Processing PMC11894984.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11894984.txt
#
# Processing PMC10899802.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10899802.txt
#
# Processing PMC12212990.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12212990.txt
#
# Processing PMC8887958.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8887958.txt
#
# Processing PMC10769466.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10769466.txt
#
# Processing PMC5713468.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5713468.txt
#
# Processing PMC11399778.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11399778.txt
#
# Processing PMC8454293.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8454293.txt
#
# Processing PMC8519814.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8519814.txt
#
# Processing PMC8064354.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8064354.txt
#
# Processing PMC9420909.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9420909.txt
#
# Processing PMC8874365.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8874365.txt
#
# Processing PMC7861009.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7861009.txt
#
# Processing PMC8537163.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8537163.txt
#
# Processing PMC7830668.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7830668.txt
#
# Processing PMC8148096.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8148096.txt
#
# Processing PMC8228432.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8228432.txt
#
# Processing PMC7565266.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7565266.txt
#
# Processing PMC7466451.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7466451.txt
#
# Processing PMC11965926.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11965926.txt
#
# Processing PMC6685390.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6685390.txt
#
# Processing PMC7890195.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7890195.txt
#
# Processing PMC8225126.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8225126.txt
#
# Processing PMC7553736.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7553736.txt
#
# Processing PMC9418125.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9418125.txt
#
# Processing PMC8269185.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8269185.txt
#
# Processing PMC8954990.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8954990.txt
#
# Processing PMC9935699.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9935699.txt
#
# Processing PMC7079582.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7079582.txt
#
# Processing PMC7831080.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7831080.txt
#
# Processing PMC7564019.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7564019.txt
#
# Processing PMC5512149.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5512149.txt
#
# Processing PMC7754704.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7754704.txt
#
# Processing PMC11988481.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11988481.txt
#
# Processing PMC10228381.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10228381.txt
#
# Processing PMC8196934.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8196934.txt
#
# Processing PMC8589429.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8589429.txt
#
# Processing PMC9025045.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9025045.txt
#
# Processing PMC7522676.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7522676.txt
#
# Processing PMC8233841.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8233841.txt
#
# Processing PMC10771564.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10771564.txt
#
# Processing PMC7755367.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7755367.txt
#
# Processing PMC7325873.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7325873.txt
#
# Processing PMC7058986.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7058986.txt
#
# Processing PMC10892965.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10892965.txt
#
# Processing PMC8479502.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8479502.txt
#
# Processing PMC8310376.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8310376.txt
#
# Processing PMC8901091.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8901091.txt
#
# Processing PMC12115334.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12115334.txt
#
# Processing PMC12280796.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12280796.txt
#
# Processing PMC9062866.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9062866.txt
#
# Processing PMC5003177.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5003177.txt
#
# Processing PMC6963306.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6963306.txt
#
# Processing PMC7812224.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7812224.txt
#
# Processing PMC9399815.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9399815.txt
#
# Processing PMC11349682.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11349682.txt
#
# Processing PMC7930017.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7930017.txt
#
# Processing PMC11532300.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11532300.txt
#
# Processing PMC10685800.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10685800.txt
#
# Processing PMC8001307.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8001307.txt
#
# Processing PMC7563944.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7563944.txt
#
# Processing PMC8632753.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8632753.txt
#
# Processing PMC10140998.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10140998.txt
#
# Processing PMC9073025.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9073025.txt
#
# Processing PMC8803737.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8803737.txt
#
# Processing PMC7870421.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7870421.txt
#
# Processing PMC10977380.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10977380.txt
#
# Processing PMC7854307.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7854307.txt
#
# Processing PMC12087419.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12087419.txt
#
# Processing PMC7660516.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7660516.txt
#
# Processing PMC8230341.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8230341.txt
#
# Processing PMC11594041.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11594041.txt
#
# Processing PMC7744276.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7744276.txt
#
# Processing PMC10610367.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10610367.txt
#
# Processing PMC8622245.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8622245.txt
#
# Processing PMC9487851.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9487851.txt
#
# Processing PMC9891683.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9891683.txt
#
# Processing PMC10764465.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10764465.txt
#
# Processing PMC9502241.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9502241.txt
#
# Processing PMC9127683.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9127683.txt
#
# Processing PMC9714609.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9714609.txt
#
# Processing PMC10172599.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10172599.txt
#
# Processing PMC8210608.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8210608.txt
#
# Processing PMC9284505.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9284505.txt
#
# Processing PMC5490820.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5490820.txt
#
# Processing PMC5398647.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5398647.txt
#
# Processing PMC9810991.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9810991.txt
#
# Processing PMC7786054.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7786054.txt
#
# Processing PMC12282282.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12282282.txt
#
# Processing PMC7711671.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7711671.txt
#
# Processing PMC8293096.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8293096.txt
#
# Processing PMC8024446.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8024446.txt
#
# Processing PMC5408242.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5408242.txt
#
# Processing PMC10745672.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10745672.txt
#
# Processing PMC8491763.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8491763.txt
#
# Processing PMC12123219.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12123219.txt
#
# Processing PMC11934161.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11934161.txt
#
# Processing PMC8664555.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8664555.txt
#
# Processing PMC8915915.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8915915.txt
#
# Processing PMC7458800.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7458800.txt
#
# Processing PMC8486642.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8486642.txt
#
# Processing PMC8523302.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8523302.txt
#
# Processing PMC11392011.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11392011.txt
#
# Processing PMC9788085.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9788085.txt
#
# Processing PMC6060342.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6060342.txt
#
# Processing PMC8470303.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8470303.txt
#
# Processing PMC9758618.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9758618.txt
#
# Processing PMC5770372.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5770372.txt
#
# Processing PMC8446444.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8446444.txt
#
# Processing PMC12162921.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12162921.txt
#
# Processing PMC6678067.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6678067.txt
#
# Processing PMC11430029.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11430029.txt
#
# Processing PMC6054431.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6054431.txt
#
# Processing PMC6789792.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6789792.txt
#
# Processing PMC7431966.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7431966.txt
#
# Processing PMC5850400.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5850400.txt
#
# Processing PMC6024737.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6024737.txt
#
# Processing PMC7430291.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7430291.txt
#
# Processing PMC11979519.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11979519.txt
#
# Processing PMC11598775.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11598775.txt
#
# Processing PMC11603676.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11603676.txt
#
# Processing PMC6904299.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6904299.txt
#
# Processing PMC5646730.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5646730.txt
#
# Processing PMC9472710.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9472710.txt
#
# Processing PMC7921795.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7921795.txt
#
# Processing PMC6288298.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6288298.txt
#
# Processing PMC5192354.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5192354.txt
#
# Processing PMC7794055.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7794055.txt
#
# Processing PMC9798670.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9798670.txt
#
# Processing PMC10138304.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10138304.txt
#
# Processing PMC7283733.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7283733.txt
#
# Processing PMC4979228.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC4979228.txt
#
# Processing PMC9998920.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9998920.txt
#
# Processing PMC10818334.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10818334.txt
#
# Processing PMC7825707.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7825707.txt
#
# Processing PMC11564800.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11564800.txt
#
# Processing PMC7223957.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7223957.txt
#
# Processing PMC8920137.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8920137.txt
#
# Processing PMC4844615.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC4844615.txt
#
# Processing PMC10113164.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10113164.txt
#
# Processing PMC7527307.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7527307.txt
#
# Processing PMC7670910.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7670910.txt
#
# Processing PMC7729279.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7729279.txt
#
# Processing PMC5041019.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5041019.txt
#
# Processing PMC9228553.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9228553.txt
#
# Processing PMC7923097.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7923097.txt
#
# Processing PMC10848012.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10848012.txt
#
# Processing PMC8294057.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8294057.txt
#
# Processing PMC5985299.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5985299.txt
#
# Processing PMC6425500.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6425500.txt
#
# Processing PMC7097181.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7097181.txt
#
# Processing PMC7193113.xml...
# ...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10504489.txt
#
# Processing PMC8579696.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8579696.txt
#
# Processing PMC7706592.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7706592.txt
#
# Processing PMC11019864.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11019864.txt
#
# Processing PMC8461619.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8461619.txt
#
# Processing PMC9316869.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9316869.txt
#
# Processing PMC9047024.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9047024.txt
#
# Processing PMC7566192.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7566192.txt
#
# Processing PMC10519952.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10519952.txt
#
# Processing PMC8385298.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8385298.txt
#
# Processing PMC9349967.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9349967.txt
#
# Processing PMC11554463.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11554463.txt
#
# Processing PMC5934487.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5934487.txt
#
# Processing PMC11680411.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11680411.txt
#
# Processing PMC8778544.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8778544.txt
#
# Processing PMC8015872.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8015872.txt
#
# Processing PMC7264115.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7264115.txt
#
# Processing PMC8204314.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8204314.txt
#
# Processing PMC9046659.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9046659.txt
#
# Processing PMC8461057.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8461057.txt
#
# Processing PMC8489670.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8489670.txt
#
# Processing PMC7426751.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7426751.txt
#
# Processing PMC7942141.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7942141.txt
#
# Processing PMC9787869.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9787869.txt
#
# Processing PMC9918406.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9918406.txt
#
# Processing PMC8693424.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8693424.txt
#
# Processing PMC11290775.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11290775.txt
#
# Processing PMC11719530.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11719530.txt
#
# Processing PMC8127454.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8127454.txt
#
# Processing PMC12113167.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12113167.txt
#
# Processing PMC9014240.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9014240.txt
#
# Processing PMC7779084.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7779084.txt
#
# Processing PMC9576584.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9576584.txt
#
# Processing PMC8023785.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8023785.txt
#
# Processing PMC6579862.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6579862.txt
#
# Processing PMC4933989.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC4933989.txt
#
# Processing PMC7260568.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7260568.txt
#
# Processing PMC4758146.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC4758146.txt
#
# Processing PMC6663142.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6663142.txt
#
# Processing PMC8695322.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8695322.txt
#
# Processing PMC11596275.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11596275.txt
#
# Processing PMC8363864.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8363864.txt
#
# Processing PMC5351694.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5351694.txt
#
# Processing PMC7318960.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7318960.txt
#
# Processing PMC8248554.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8248554.txt
#
# Processing PMC12188742.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12188742.txt
#
# Processing PMC8994861.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8994861.txt
#
# Processing PMC11436118.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11436118.txt
#
# Processing PMC9188855.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9188855.txt
#
# Processing PMC9863728.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9863728.txt
#
# Processing PMC7595841.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7595841.txt
#
# Processing PMC8373118.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8373118.txt
#
# Processing PMC9100302.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9100302.txt
#
# Processing PMC10897055.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10897055.txt
#
# Processing PMC11494027.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11494027.txt
#
# Processing PMC8691362.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8691362.txt
#
# Processing PMC9732709.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9732709.txt
#
# Processing PMC11315725.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11315725.txt
#
# Processing PMC8088038.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8088038.txt
#
# Processing PMC8006194.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8006194.txt
#
# Processing PMC6723941.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6723941.txt
#
# Processing PMC8002393.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8002393.txt
#
# Processing PMC8127526.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8127526.txt
#
# Processing PMC11679499.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11679499.txt
#
# Processing PMC8069344.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8069344.txt
#
# Processing PMC5806658.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5806658.txt
#
# Processing PMC11172503.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11172503.txt
#
# Processing PMC9271922.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9271922.txt
#
# Processing PMC7356751.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7356751.txt
#
# Processing PMC10220683.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10220683.txt
#
# Processing PMC10097995.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10097995.txt
#
# Processing PMC6943637.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6943637.txt
#
# Processing PMC5085676.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5085676.txt
#
# Processing PMC7591944.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7591944.txt
#
# Processing PMC7554600.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7554600.txt
#
# Processing PMC8532523.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8532523.txt
#
# Processing PMC9728475.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9728475.txt
#
# Processing PMC10805787.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10805787.txt
#
# Processing PMC7770879.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7770879.txt
#
# Processing PMC9017465.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9017465.txt
#
# Processing PMC6262758.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6262758.txt
#
# Processing PMC7775495.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7775495.txt
#
# Processing PMC11980946.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11980946.txt
#
# Processing PMC7963163.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7963163.txt
#
# Processing PMC10874560.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10874560.txt
#
# Processing PMC7749790.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7749790.txt
#
# Processing PMC9372928.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9372928.txt
#
# Processing PMC7521454.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7521454.txt
#
# Processing PMC9470835.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9470835.txt
#
# Processing PMC9325128.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9325128.txt
#
# Processing PMC6498404.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6498404.txt
#
# Processing PMC10975474.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10975474.txt
#
# Processing PMC7094556.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7094556.txt
#
# Processing PMC9892189.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9892189.txt
#
# Processing PMC9085459.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9085459.txt
#
# Processing PMC10401146.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10401146.txt
#
# Processing PMC7789827.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7789827.txt
#
# Processing PMC7677582.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7677582.txt
#
# Processing PMC8541031.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8541031.txt
#
# Processing PMC8624722.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8624722.txt
#
# Processing PMC9980607.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9980607.txt
#
# Processing PMC9715960.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9715960.txt
#
# Processing PMC6222055.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6222055.txt
#
# Processing PMC8364403.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8364403.txt
#
# Processing PMC9087965.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9087965.txt
#
# Processing PMC6524688.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6524688.txt
#
# Processing PMC11125608.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11125608.txt
#
# Processing PMC7498663.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7498663.txt
#
# Processing PMC11206999.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11206999.txt
#
# Processing PMC10538607.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10538607.txt
#
# Processing PMC9697487.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9697487.txt
#
# Processing PMC9654069.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9654069.txt
#
# Processing PMC9863224.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9863224.txt
#
# Processing PMC11481298.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11481298.txt
#
# Processing PMC9506058.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9506058.txt
#
# Processing PMC11662099.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11662099.txt
#
# Processing PMC8483762.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8483762.txt
#
# Processing PMC7759937.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7759937.txt
#
# Processing PMC10064963.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10064963.txt
#
# Processing PMC6436086.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6436086.txt
#
# Processing PMC8427162.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8427162.txt
#
# Processing PMC7444935.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7444935.txt
#
# Processing PMC5740944.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5740944.txt
#
# Processing PMC5578107.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC5578107.txt
#
# Processing PMC12133506.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC12133506.txt
#
# Processing PMC8974753.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8974753.txt
#
# Processing PMC11562918.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11562918.txt
#
# Processing PMC6414784.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC6414784.txt
#
# Processing PMC9962240.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC9962240.txt
#
# Processing PMC10760363.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC10760363.txt
#
# Processing PMC11858333.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11858333.txt
#
# Processing PMC8310046.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8310046.txt
#
# Processing PMC8225681.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8225681.txt
#
# Processing PMC8984165.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8984165.txt
#
# Processing PMC11359700.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC11359700.txt
#
# Processing PMC8572789.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8572789.txt
#
# Processing PMC8615473.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8615473.txt
#
# Processing PMC8310105.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8310105.txt
#
# Processing PMC7194727.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC7194727.txt
#
# Processing PMC8707864.xml...
#  -> Saved plaintext to Dataset/PMC_Filtered_Reviews_plaintext_gemini/PMC8707864.txt
