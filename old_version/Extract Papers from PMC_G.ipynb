# %%
# PMC fulltext Save in single and separate both at the same time
import os
import requests
from xml.etree import ElementTree

def search_pmc_ids(keyword, retmax=1000):
    print(f"🔍 Searching PMC for: {keyword}")
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pmc",
        "term": keyword + " open access[filter]",
        "retmax": retmax,
        "retmode": "xml"
    }

    response = requests.get(base_url, params=params)
    response.raise_for_status()
    root = ElementTree.fromstring(response.content)
    return [elem.text for elem in root.findall(".//Id")]

def fetch_pmc_article_xml(pmcid):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    params = {
        "db": "pmc",
        "id": pmcid,
        "retmode": "xml"
    }

    response = requests.get(base_url, params=params)
    response.raise_for_status()
    return response.text

def save_pmc_xml(xml_data, pmcid, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    filepath = os.path.join(output_folder, f"PMC{pmcid}.xml")
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(xml_data)
    print(f"✅ Saved: {filepath}")

# === MAIN ===
if __name__ == "__main__":
    keyword = "Alum vaccine adjuvant immune mechanism"
    output_dir = "Dataset/Dataset_PMC"

    pmc_ids = search_pmc_ids(keyword)

    if not pmc_ids:
        print("❌ No full-text articles found in PMC.")
    else:
        for pmcid in pmc_ids:
            try:
                xml = fetch_pmc_article_xml(pmcid)
                save_pmc_xml(xml, pmcid, output_dir)
            except Exception as e:
                print(f"⚠️ Failed for PMC{pmcid}: {e}")
# Out:
# 🔍 Searching PMC for: Alum vaccine adjuvant immune mechanism
# ❌ No full-text articles found in PMC.

# %%
# PMC fulltext with boolean query Save in single and separate both at the same time
import os
import requests
import time
from xml.etree import ElementTree

def get_boolean_query():
    return (
        '("aluminum sulfate"[Supplementary Concept] OR "aluminum sulfate"[All Fields] OR "alum"[All Fields]) '
        'AND ("adjuvants, vaccine"[Supplementary Concept] OR "adjuvants, vaccine"[All Fields] OR "vaccine adjuvant"[All Fields] '
        'OR "adjuvants, vaccine"[MeSH Terms] OR ("adjuvants"[All Fields] AND "vaccine"[All Fields]) '
        'OR "vaccine adjuvants"[All Fields] OR ("vaccine"[All Fields] AND "adjuvant"[All Fields])) '
        'AND ("immunity"[MeSH Terms] OR "immunity"[All Fields] OR ("immune"[All Fields] AND "response"[All Fields]) '
        'OR "immune response"[All Fields]) AND mechanism[All Fields]'
    )

    

def search_pmc(query, retmax=10000):
    print("🔍 Searching PMC...")
    url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pmc",
        "term": query,
        "retmode": "xml",
        "retmax": retmax
    }
    response = requests.get(url, params=params)
    response.raise_for_status()

    root = ElementTree.fromstring(response.content)
    pmc_ids = [id_elem.text for id_elem in root.findall(".//Id")]
    print(f"✅ Found {len(pmc_ids)} PMC IDs.")
    return pmc_ids

def fetch_pmc_article_xml(pmcid):
    url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    params = {
        "db": "pmc",
        "id": pmcid,
        "retmode": "xml"
    }
    response = requests.get(url, params=params)
    response.raise_for_status()
    return response.text

def save_xml(xml_data, pmcid, output_dir):
    os.makedirs(output_dir, exist_ok=True)
xml
# 📄 Saved: Dataset/Dataset_PMC/PMC88944.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97535.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97524.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97487.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97485.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97479.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2374519.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2327186.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97406.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97393.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97391.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC111786.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97300.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2327145.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97189.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97101.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC113066.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC113034.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97069.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97042.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC97029.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2326954.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2326936.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC96924.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC95784.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1905361.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC96760.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC22232.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC96741.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC96665.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC96645.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC7134157.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC112651.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2326828.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC96578.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC115976.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC115957.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC96361.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC96351.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2212427.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1745117.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1364407.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC108666.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC108628.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2213399.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC108488.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2213364.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC88894.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1858452.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC108152.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC109732.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC108082.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC108081.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC107993.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2212158.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2230303.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1364104.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1364099.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC121373.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC107852.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC25074.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC175635.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC23701.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC175619.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC172935.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC175443.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC23851.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC175330.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC175313.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC508048.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1456710.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1189365.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC190926.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC174522.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1456540.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC190848.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1263845.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC174350.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC172909.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC174259.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC174116.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC174091.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1952187.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC173890.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC7148745.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1383977.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC40440.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC173690.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC228567.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC189487.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC173527.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1553258.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC173391.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2191967.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC303304.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC303154.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC303107.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1415016.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC303051.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC44640.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC302951.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC263914.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC358327.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC358325.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC302888.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC296308.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1534568.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC236595.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1422217.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1421923.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2191068.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC288196.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1421888.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC372905.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC302742.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC302690.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC50665.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC240354.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1421720.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC258218.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC270486.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC49907.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC49794.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC257302.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC257248.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC49137.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC238273.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC259062.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC258122.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC51736.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC257900.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC54356.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC258671.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC250917.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC358122.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2189359.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC313241.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC303766.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1542039.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC259587.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC253681.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC373137.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC259413.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC259771.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2491173.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1542085.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1453375.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC213519.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1474689.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1577265.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2187644.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1418009.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1305978.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2536442.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2187471.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC263350.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC264606.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC459575.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2306702.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC551426.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC256054.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC351511.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1438342.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1458158.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2185900.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2185884.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2395980.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1537962.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2185689.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2185669.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2185640.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC414441.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2042324.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC414132.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1277802.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2180815.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1445342.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC414000.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2367087.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2366742.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1445198.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1445196.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1445138.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1697302.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2032397.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1446028.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1445931.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC415111.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1696630.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1445613.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1474938.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1554072.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC413841.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2481136.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2481108.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2481022.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1408005.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2139260.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC378454.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1553676.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1408189.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC416325.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1713074.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1469182.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2370131.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1712875.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1455597.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1455535.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2427500.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2427593.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1503384.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1579011.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1409532.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1409462.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2591613.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC292688.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1423580.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2166272.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1423401.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1423418.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1515493.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1915462.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1423274.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1423228.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC278112.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1424173.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC441101.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1953472.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2098602.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC181320.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2136862.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1829839.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2082586.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2538016.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2538008.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC182568.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2542137.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC1877218.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2554092.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2286412.xml
# 📄 Saved: Dataset/Dataset_PMC/PMC2260034.xml

# %%
import os
from xml.etree import ElementTree
from collections import Counter

def detect_article_type(xml_path):
    try:
        tree = ElementTree.parse(xml_path)
        root = tree.getroot()
        article = root.find(".//article")
        if article is not None:
            article_type = article.attrib.get("article-type", "").lower()
            return article_type if article_type else "unknown"
    except Exception as e:
        print(f"⚠️ Failed to parse {xml_path}: {e}")
    return "unknown"

def summarize_article_types(folder):
    stats = Counter()
    files = [f for f in os.listdir(folder) if f.endswith(".xml")]
    total = len(files)

    for filename in files:
        path = os.path.join(folder, filename)
        article_type = detect_article_type(path)
        stats[article_type] += 1

    print(f"📊 Stats from folder: {folder}")
    print(f"Total articles: {total}")
    for art_type, count in stats.items():
        print(f"- {art_type}: {count}")
    return stats

# === MAIN ===
if __name__ == "__main__":
    folder = "Dataset/Dataset_PMC"  # Change if needed
    summarize_article_types(folder)
# Out:
# 📊 Stats from folder: Dataset/Dataset_PMC
# Total articles: 7029
# - research-article: 4654
# - abstract: 21
# - review-article: 2060
# - chapter-article: 65
# - brief-report: 61
# - editorial: 28
# - discussion: 9
# - methods-article: 2
# - other: 43
# - news: 7
# - article-commentary: 20
# - meeting-report: 14
# - systematic-review: 13
# - case-report: 10
# - in-brief: 2
# - calendar: 3
# - reply: 5
# - rapid-communication: 5
# - letter: 5
# - product-review: 2

# %%
import os
from xml.etree import ElementTree
import shutil

SOURCE_DIR = "Dataset/Dataset_PMC"
DEST_DIR = "Dataset/Dataset_PMC_Filtered"
os.makedirs(DEST_DIR, exist_ok=True)

def has_full_text(root):
    return root.find(".//body") is not None

def is_nih_funded(root):
    text = ElementTree.tostring(root, encoding="utf-8").decode().lower()
    return "nih" in text or "national institutes of health" in text

def get_publication_year(root):
    year_elem = root.find(".//pub-date/year")
    if year_elem is not None and year_elem.text and year_elem.text.isdigit():
        return int(year_elem.text)
    return None

def filter_pmc_articles(source_dir, dest_dir):
    total = 0
    matched = 0

    for fname in os.listdir(source_dir):
        if not fname.endswith(".xml"):
            continue
        total += 1
        src_path = os.path.join(source_dir, fname)

        try:
            root = ElementTree.parse(src_path).getroot()
        except Exception as e:
            print(f"⚠️ Failed to parse {fname}: {e}")
            continue

        if not has_full_text(root):
            continue
        if not is_nih_funded(root):
            continue
        pub_year = get_publication_year(root)
        if pub_year is None or pub_year <= 2015:
            continue

        # All filters passed — copy the file
        dst_path = os.path.join(dest_dir, fname)
        shutil.copy(src_path, dst_path)
        matched += 1

    print(f"\n📊 Filter Summary:")
    print(f"Total scanned: {total}")
    print(f"Matched (fulltext, NIH, year>2015): {matched}")

# === MAIN ===
if __name__ == "__main__":
    filter_pmc_articles(SOURCE_DIR, DEST_DIR)
# Out:
# 📊 Filter Summary:
# Total scanned: 7029
# Matched (fulltext, NIH, year>2015): 1674

# %%
import os
from xml.etree import ElementTree
import shutil

SOURCE_DIR = "Dataset/Dataset_PMC_Filtered"
DEST_DIR = "Dataset/Dataset_PMC_Filtered_Reviews"
os.makedirs(DEST_DIR, exist_ok=True)

TARGET_TYPES = {"review-article", "systematic-review"}

def get_article_type(root):
    article = root.find(".//article")
    return article.attrib.get("article-type", "unknown") if article is not None else "unknown"

def filter_review_articles(source_dir, dest_dir):
    total = 0
    matched = 0

    for fname in os.listdir(source_dir):
        if not fname.endswith(".xml"):
            continue
        total += 1
        path = os.path.join(source_dir, fname)

        try:
            root = ElementTree.parse(path).getroot()
            article_type = get_article_type(root)
        except Exception as e:
            print(f"⚠️ Error parsing {fname}: {e}")
            continue

        if article_type in TARGET_TYPES:
            shutil.copy(path, os.path.join(dest_dir, fname))
            matched += 1

    print(f"\n📊 Review Filtering Summary:")
    print(f"Total scanned: {total}")
    print(f"Matched reviews: {matched}")

# === MAIN ===
if __name__ == "__main__":
    filter_review_articles(SOURCE_DIR, DEST_DIR)
# Out:
# 📊 Review Filtering Summary:
# Total scanned: 1674
# Matched reviews: 603
